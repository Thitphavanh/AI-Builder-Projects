# %% [markdown]
# ## **Object detection ด้วย FastAI**
#
# Object detection การสร้างโมเดลมาเพื่อทำนายบริเวณที่มีวัตถุที่สนใจ และหลังจากนั้นทำนายว่าวัตถุในบริเวณที่สนใจเป็นวัตถุประเภทใด
#
# ในตัวอย่างนี้เราจะนำชุดข้อมูลจาก Kaggle: [Monkey, Cat and Dog detection](https://www.kaggle.com/datasets/tarunbisht11/yolo-animal-detection-small) มาตรวจจับและแยกประเภทของข้าวสาลีกัน
#
# ใน Notebook นี้เราจะทำการ
# - โหลดชุดข้อมูล
# - สร้างไฟล์ Object detection ในรูปแบบของ COCO format
# - รัน Object detection ด้วย FastAI

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in c:\python310\lib\site-packages (1.5.12)
# Requirement already satisfied: python-slugify in c:\python310\lib\site-packages (from kaggle) (6.1.2)
# Requirement already satisfied: tqdm in c:\python310\lib\site-packages (from kaggle) (4.64.0)
# Requirement already satisfied: urllib3 in c:\python310\lib\site-packages (from kaggle) (1.26.9)
# Requirement already satisfied: requests in c:\python310\lib\site-packages (from kaggle) (2.27.1)
# Requirement already satisfied: certifi in c:\python310\lib\site-packages (from kaggle) (2022.5.18.1)
# Requirement already satisfied: six>=1.10 in c:\python310\lib\site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: python-dateutil in c:\python310\lib\site-packages (from kaggle) (2.8.2)
# Requirement already satisfied: text-unidecode>=1.3 in c:\python310\lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\python310\lib\site-packages (from requests->kaggle) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\python310\lib\site-packages (from requests->kaggle) (2.0.12)
# Requirement already satisfied: colorama in c:\python310\lib\site-packages (from tqdm->kaggle) (0.4.4)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !kaggle datasets download -d tarunbisht11/yolo-animal-detection-small
# Out:
# Traceback (most recent call last):
#   File "C:\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "C:\Python310\Scripts\kaggle.exe\__main__.py", line 4, in <module>
#   File "C:\Python310\lib\site-packages\kaggle\__init__.py", line 23, in <module>
#     api.authenticate()
#   File "C:\Python310\lib\site-packages\kaggle\api\kaggle_api_extended.py", line 164, in authenticate
#     raise IOError('Could not find {}. Make sure it\'s located in'
# OSError: Could not find kaggle.json. Make sure it's located in C:\Users\Hery\.kaggle. Or use the environment method.

# %%
# !unzip yolo-animal-detection-small.zip -d yolo-animal-small
# Out:
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !git clone https://github.com/muellerzr/Practical-Deep-Learning-for-Coders-2.0
# Out:
# fatal: destination path 'Practical-Deep-Learning-for-Coders-2.0' already exists and is not an empty directory.

# %% [markdown]
# ## **สร้าง COCO Dataset จากชุดข้อมูล CSV**

# %%
import json
import ast
import pandas as pd
import os.path as op
from pathlib import Path
from PIL import Image

# %%
annotation_df = pd.read_csv(r"C:/Users/Hery\Desktop/My Projects/Python-Python-Artificial-intelligence-Machine-Learning-Deep-Learning-Bootcamp/curriculum/notebooks/yolo-animal-small/yolo-animal-detection-small/train.csv")
annotation_df.head()
# Out:
#        filename  width  height class  xmin  ymin  xmax  ymax
# 0  cats_001.jpg    474     266   cat   132     1   347   264
# 1  cats_002.jpg    474     474   cat   176    44   467   433
# 2  cats_003.jpg    474     314   cat    53     1   397   314
# 3  cats_004.jpg    474     355   cat     1     1   393   335
# 4  cats_005.jpg    474     316   cat    80     1   407   316

# %%
Image.open("yolo-animal-small/yolo-animal-detection-small/train/cats_and_monkeys_097.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x378>

# %%
annotation_df["bbox"] = annotation_df.apply(
    lambda r: [r["xmin"], r["ymin"], r["xmax"] - r["xmin"], r["ymax"] - r["ymin"]],
    axis=1
)
annotation_df["area"] = annotation_df.apply(lambda r: r["bbox"][2] * r["bbox"][3], axis=1)
annotation_df["id"] = annotation_df.filename.map(lambda x: Path(x).stem)

# %%
annotation_df.head()
# Out:
#        filename  width  height class  xmin  ymin  xmax  ymax  \
# 0  cats_001.jpg    474     266   cat   132     1   347   264
# 1  cats_002.jpg    474     474   cat   176    44   467   433
# 2  cats_003.jpg    474     314   cat    53     1   397   314
# 3  cats_004.jpg    474     355   cat     1     1   393   335
# 4  cats_005.jpg    474     316   cat    80     1   407   316
#
#                   bbox    area        id
# 0   [132, 1, 215, 263]   56545  cats_001
# 1  [176, 44, 291, 389]  113199  cats_002
# 2    [53, 1, 344, 313]  107672  cats_003
# 3     [1, 1, 392, 334]  130928  cats_004
# 4    [80, 1, 327, 315]  103005  cats_005

# %%
img_df = annotation_df.groupby("id").first().reset_index()[["id", "width", "height"]]
img_df["file_name"] = img_df.id.map(lambda p: op.join("yolo-animal-small/yolo-animal-detection-small/train/", f"{p}.jpg"))

# %%
img_df.head()
# Out:
#          id  width  height  \
# 0  cats_001    474     266
# 1  cats_002    474     474
# 2  cats_003    474     314
# 3  cats_004    474     355
# 4  cats_005    474     316
#
#                                                           file_name
# 0  yolo-animal-small/yolo-animal-detection-small/train/cats_001.jpg
# 1  yolo-animal-small/yolo-animal-detection-small/train/cats_002.jpg
# 2  yolo-animal-small/yolo-animal-detection-small/train/cats_003.jpg
# 3  yolo-animal-small/yolo-animal-detection-small/train/cats_004.jpg
# 4  yolo-animal-small/yolo-animal-detection-small/train/cats_005.jpg

# %%
images = img_df.to_dict("records")

categories = []
for i, c in enumerate(annotation_df["class"].unique()):
    categories.append({"supercategory": "animal", "id": i, "name": c})
cat2idx = {r["name"]: r["id"] for r in categories}

# %%
categories
# Out:
# [{'supercategory': 'animal', 'id': 0, 'name': 'cat'},
#  {'supercategory': 'animal', 'id': 1, 'name': 'monkey'},
#  {'supercategory': 'animal', 'id': 2, 'name': 'dog'}]

# %%
annotation_df["category_id"] = annotation_df["class"].map(cat2idx)

# %%
annotation_df.head()
# Out:
#        filename  width  height class  xmin  ymin  xmax  ymax  \
# 0  cats_001.jpg    474     266   cat   132     1   347   264
# 1  cats_002.jpg    474     474   cat   176    44   467   433
# 2  cats_003.jpg    474     314   cat    53     1   397   314
# 3  cats_004.jpg    474     355   cat     1     1   393   335
# 4  cats_005.jpg    474     316   cat    80     1   407   316
#
#                   bbox    area        id  category_id
# 0   [132, 1, 215, 263]   56545  cats_001            0
# 1  [176, 44, 291, 389]  113199  cats_002            0
# 2    [53, 1, 344, 313]  107672  cats_003            0
# 3     [1, 1, 392, 334]  130928  cats_004            0
# 4    [80, 1, 327, 315]  103005  cats_005            0

# %%
annotation_df.rename(columns={"id": "image_id"}, inplace=True)

# %%
annotation_df["id"] = list(range(len(annotation_df)))
annotation_df["iscrowd"] = 0

# %%
annotations = annotation_df[["id", "category_id", "iscrowd", "bbox", "image_id", "area"]].to_dict("records")

# %%
coco_format = {
    "info": {"description": "Monkey Cat Dog Dataset from Kaggle", "url": "https://www.kaggle.com/datasets/tarunbisht11/yolo-animal-detection-small"},
    "licenses": [
        {"url": "https://www.kaggle.com/datasets/tarunbisht11/yolo-animal-detection-small"}
    ],
    "images": images,
    "annotations": annotations,
    "categories": categories
}

# %%
json.dump(coco_format, open("yolo-animal-small/coco_format.json", "w"), indent=2)

# %%
coco_format_load = json.load(open("yolo-animal-small/coco_format.json", "r"))

# %% [markdown]
# ## **FastAI for Object detection**
#
# Description: https://walkwithfastai.com/Object_Detection
# Reference: https://youtu.be/5bSVug1YB3s?t=2067

# %%
from fastbook import *
from fastai.vision.all import *

# add path ไปยัง Github ที่ clone มา
import sys
sys.path.append('Practical-Deep-Learning-for-Coders-2.0/Computer Vision/')
from imports import *

# %%
# คำสั่งของ FastAI เพื่อได้ภาพ และ label boxes สำหรับแต่ละภาพ
imgs, label_bbox = get_annotations("yolo-animal-small/coco_format.json")
img2bbox = dict(zip(imgs, label_bbox))

# %%
# place holder สำหรับ get_items
def get_train_images(noop = None):
    return imgs

# %%
images = get_train_images()

# %%
funcs = [lambda o: o, lambda o: img2bbox[o][0], lambda o: img2bbox[o][1]]
item_tfms = [Resize(224)]
batch_tfms = [Rotate(), Flip(), Dihedral(), Normalize.from_stats(*imagenet_stats)]

wheat_datablock = DataBlock(
    blocks=(ImageBlock, BBoxBlock, BBoxLblBlock),
    splitter=RandomSplitter(valid_pct=0.2),
    get_items=get_train_images,
    getters=funcs,
    item_tfms=item_tfms,
    batch_tfms=batch_tfms,
    n_inp=1
)

# %%
dls = wheat_datablock.dataloaders("yolo-animal-small/yolo-animal-detection-small/train/")
dls.c = 3
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
dls.show_batch(max_n=10)

# %%
encoder = create_body(resnet34, pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to C:\Users\Hery/.cache\torch\hub\checkpoints\resnet34-b627a593.pth
# 100%|██████████| 83.3M/83.3M [02:39<00:00, 549kB/s]

# %%
get_c(dls) # นับจำนวน Class
# Out:
# 3

# %%
# สร้าง RetinaNet ด้วย Resnet34 encoder 
retina_net = RetinaNet(encoder, get_c(dls), final_bias=-4)

# %%
retina_net.box_regressor
# Out:
# Sequential(
#   (0): ConvLayer(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (1): ConvLayer(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (2): ConvLayer(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (3): ConvLayer(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (4): Conv2d(256, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %%
criterion = RetinaNetFocalLoss(scales=[1, 2**(-1/3), 2**(-2/3)], ratios=[1/2, 1, 2])

# %%
def _retinanet_split(m):
    return L(
        m.encoder,
        nn.Sequential(m.c5top6, m.p6top7, m.merges, m.smoothers, m.classifier, m.box_regressor)
    ).map(params)

# %%
learner = Learner(dls, retina_net, loss_func=criterion, splitter=_retinanet_split)

# %%
learner.freeze()

# %%
# มี error จาก FastAI
# ref: https://forums.fast.ai/t/typeerror-no-implementation-found-for-torch-nn-functional-smooth-l1-loss-on-types-that-implement-torch-function-class-fastai-torch-core-tensorimage-class-fastai-vision-core-tensorbbox/90897
# ที่สามารถแก้ได้ด้วยบรรทัดต่อไปนี้
TensorImage.register_func(torch.nn.functional.smooth_l1_loss, TensorImage, TensorBBox)
TensorMultiCategory.register_func(TensorMultiCategory.mul, TensorMultiCategory, TensorImage)
TensorImage.register_func(torch.nn.functional.binary_cross_entropy_with_logits, TensorImage, TensorMultiCategory)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Hery\Desktop\My Projects\Python-Python-Artificial-intelligence-Machine-Learning-Deep-Learning-Bootcamp\curriculum\notebooks\05v_object_detection.ipynb Cell 40 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Hery/Desktop/My%20Projects/Python-Python-Artificial-intelligence-Machine-Learning-Deep-Learning-Bootcamp/curriculum/notebooks/05v_object_detection.ipynb#ch0000039?line=0'>1</a> # มี error จาก FastAI
#       <a href='vscode-notebook-cell:/c%3A/Users/Hery/Desktop/My%20Projects/Python-Python-Artificial-intelligence-Machine-Learning-Deep-Learning-Bootcamp/curriculum/notebooks/05v_object_detection.ipynb#ch0000039?line=1'>2</a> # ref: https://forums.fast.ai/t/typeerror-no-implementation-found-for-torch-nn-functional-smooth-l1-loss-on-types-that-implement-torch-function-class-fastai-torch-core-tensorimage-class-fastai-vision-core-tensorbbox/90897
#       <a href='vscode-notebook-cell:/c%3A/Users/Hery/Desktop/My%20Projects/Python-Python-Artificial-intelligence-Machine-Learning-Deep-Learning-Bootcamp/curriculum/notebooks/05v_object_detection.ipynb#ch0000039?line=2'>3</a> # ที่สามารถแก้ได้ด้วยบรรทัดต่อไปนี้
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Hery/Desktop/My%20Projects/Python-Python-Artificial-intelligence-Machine-Learning-Deep-Learning-Bootcamp/curriculum/notebooks/05v_object_detection.ipynb#ch0000039?line=3'>4</a> TensorImage.register_func(torch.nn.functional.smooth_l1_loss, TensorImage, TensorBBox)
#       <a href='vscode-notebook-cell:/c%3A/Users/Hery/Desktop/My%20Projects/Python-Python-Artificial-intelligence-Machine-Learning-Deep-Learning-Bootcamp/curriculum/notebooks/05v_object_detection.ipynb#ch0000039?line=4'>5</a> TensorMultiCategory.register_func(TensorMultiCategory.mul, TensorMultiCategory, TensorImage)
#       <a href='vscode-notebook-cell:/c%3A/Users/Hery/Desktop/My%20Projects/Python-Python-Artificial-intelligence-Machine-Learning-Deep-Learning-Bootcamp/curriculum/notebooks/05v_object_detection.ipynb#ch0000039?line=5'>6</a> TensorImage.register_func(torch.nn.functional.binary_cross_entropy_with_logits, TensorImage, TensorMultiCategory)
#
# NameError: name 'TensorImage' is not defined

# %%
learner.fit_one_cycle(10, slice(1e-5, 1e-4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Hery\Desktop\My Projects\Python-Python-Artificial-intelligence-Machine-Learning-Deep-Learning-Bootcamp\curriculum\notebooks\05v_object_detection.ipynb Cell 41 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Hery/Desktop/My%20Projects/Python-Python-Artificial-intelligence-Machine-Learning-Deep-Learning-Bootcamp/curriculum/notebooks/05v_object_detection.ipynb#ch0000040?line=0'>1</a> learner.fit_one_cycle(10, slice(1e-5, 1e-4))
#
# NameError: name 'learner' is not defined

# %% [markdown]
# ## **Object detection ด้วย IceVision**
#
# ใน Section นี้เราจะใช้ไลบรารี่ Icevision ในการสร้างโมเดล Object detection กัน

# %%
import os.path as op
import pandas as pd
from icevision.all import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Hery\Desktop\My Projects\Python-Python-Artificial-intelligence-Machine-Learning-Deep-Learning-Bootcamp\curriculum\notebooks\05v_object_detection.ipynb Cell 43 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Hery/Desktop/My%20Projects/Python-Python-Artificial-intelligence-Machine-Learning-Deep-Learning-Bootcamp/curriculum/notebooks/05v_object_detection.ipynb#ch0000042?line=0'>1</a> import os.path as op
#       <a href='vscode-notebook-cell:/c%3A/Users/Hery/Desktop/My%20Projects/Python-Python-Artificial-intelligence-Machine-Learning-Deep-Learning-Bootcamp/curriculum/notebooks/05v_object_detection.ipynb#ch0000042?line=1'>2</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Hery/Desktop/My%20Projects/Python-Python-Artificial-intelligence-Machine-Learning-Deep-Learning-Bootcamp/curriculum/notebooks/05v_object_detection.ipynb#ch0000042?line=2'>3</a> from icevision.all import *
#
# ModuleNotFoundError: No module named 'icevision'

# %%
df = pd.read_csv("yolo-animal-small/train.csv")
df.rename(columns={"class": "label"}, inplace=True)

# %%
df.to_csv("yolo-animal-small/train_annotation.csv", index=False)

# %%
df.head()
# Out:
#        filename  width  height label  xmin  ymin  xmax  ymax
# 0  cats_001.jpg    474     266   cat   132     1   347   264
# 1  cats_002.jpg    474     474   cat   176    44   467   433
# 2  cats_003.jpg    474     314   cat    53     1   397   314
# 3  cats_004.jpg    474     355   cat     1     1   393   335
# 4  cats_005.jpg    474     316   cat    80     1   407   316

# %%
template_record = ObjectDetectionRecord()

class YoloSmallDataset(Parser):
    def __init__(self, template_record):
        super().__init__(template_record=template_record)
        self.df = pd.read_csv("yolo-animal-small/train_annotation.csv")
        self.class_map = ClassMap(list(self.df['label'].unique()))

    def __iter__(self) -> Any:
        for o in self.df.itertuples():
            yield o

    def __len__(self) -> int:
        return len(self.df)

    def record_id(self, o) -> Hashable:
        return o.filename

    def parse_fields(self, o, record, is_new):
        if is_new:
            record.set_filepath(op.join("yolo-animal-small/yolo-animal-detection-small/", "train", o.filename))
            record.set_img_size(ImgSize(width=o.width, height=o.height))
            record.detection.set_class_map(self.class_map)

        record.detection.add_bboxes([BBox.from_xyxy(o.xmin, o.ymin, o.xmax, o.ymax)])
        record.detection.add_labels([o.label])

# %%
parser = YoloSmallDataset(template_record)
train_records, valid_records = parser.parse()
# Out:
#   0%|          | 0/1309 [00:00<?, ?it/s]
# INFO     - Autofixing records | icevision.parsers.parser:parse:122
#   0%|          | 0/469 [00:00<?, ?it/s]

# %%
len(train_records), len(valid_records)
# Out:
# (375, 94)

# %%
model_type = models.mmdet.retinanet
backbone = model_type.backbones.resnet50_fpn_1x

# %%
train_tfms = tfms.A.Adapter([*tfms.A.aug_tfms(size=224, presize=512), tfms.A.Normalize()])
valid_tfms = tfms.A.Adapter([*tfms.A.resize_and_pad(224), tfms.A.Normalize()])

# %%
train_ds = Dataset(train_records, train_tfms)
valid_ds = Dataset(valid_records, valid_tfms)

# %%
train_dl = model_type.train_dl(train_ds, batch_size=8, num_workers=4, shuffle=True)
valid_dl = model_type.train_dl(train_ds, batch_size=8, num_workers=4, shuffle=False)

# %%
samples = [train_ds[10] for _ in range(5)]
show_samples(samples, ncols=3)

# %%
model = model_type.model(backbone=backbone(pretrained=True), num_classes=len(parser.class_map))
# Out:
# /home/tupleteam/.local/lib/python3.8/site-packages/mmdet/core/anchor/builder.py:16: UserWarning: ``build_anchor_generator`` would be deprecated soon, please use ``build_prior_generator``
#   warnings.warn(
# 2022-04-30 11:39:14,468 - mmcv - INFO - initialize ResNet with init_cfg {'type': 'Pretrained', 'checkpoint': 'torchvision://resnet50'}
# 2022-04-30 11:39:14,468 - mmcv - INFO - load model from: torchvision://resnet50
# 2022-04-30 11:39:14,469 - mmcv - INFO - load checkpoint from torchvision path: torchvision://resnet50
# 2022-04-30 11:39:14,511 - mmcv - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 2022-04-30 11:39:14,518 - mmcv - INFO - initialize FPN with init_cfg {'type': 'Xavier', 'layer': 'Conv2d', 'distribution': 'uniform'}
# 2022-04-30 11:39:14,549 - mmcv - INFO - initialize RetinaHead with init_cfg {'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01, 'override': {'type': 'Normal', 'name': 'retina_cls', 'std': 0.01, 'bias_prob': 0.01}}
# 2022-04-30 11:39:14,572 - mmcv - INFO -
# backbone.conv1.weight - torch.Size([64, 3, 7, 7]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,573 - mmcv - INFO -
# backbone.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,573 - mmcv - INFO -
# backbone.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,573 - mmcv - INFO -
# backbone.layer1.0.conv1.weight - torch.Size([64, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,574 - mmcv - INFO -
# backbone.layer1.0.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,574 - mmcv - INFO -
# backbone.layer1.0.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,574 - mmcv - INFO -
# backbone.layer1.0.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,574 - mmcv - INFO -
# backbone.layer1.0.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,575 - mmcv - INFO -
# backbone.layer1.0.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,575 - mmcv - INFO -
# backbone.layer1.0.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,575 - mmcv - INFO -
# backbone.layer1.0.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,575 - mmcv - INFO -
# backbone.layer1.0.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,576 - mmcv - INFO -
# backbone.layer1.0.downsample.0.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,576 - mmcv - INFO -
# backbone.layer1.0.downsample.1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,576 - mmcv - INFO -
# backbone.layer1.0.downsample.1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,577 - mmcv - INFO -
# backbone.layer1.1.conv1.weight - torch.Size([64, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,577 - mmcv - INFO -
# backbone.layer1.1.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,577 - mmcv - INFO -
# backbone.layer1.1.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,577 - mmcv - INFO -
# backbone.layer1.1.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,578 - mmcv - INFO -
# backbone.layer1.1.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,578 - mmcv - INFO -
# backbone.layer1.1.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,578 - mmcv - INFO -
# backbone.layer1.1.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,579 - mmcv - INFO -
# backbone.layer1.1.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,579 - mmcv - INFO -
# backbone.layer1.1.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,579 - mmcv - INFO -
# backbone.layer1.2.conv1.weight - torch.Size([64, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,579 - mmcv - INFO -
# backbone.layer1.2.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,580 - mmcv - INFO -
# backbone.layer1.2.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,580 - mmcv - INFO -
# backbone.layer1.2.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,580 - mmcv - INFO -
# backbone.layer1.2.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,580 - mmcv - INFO -
# backbone.layer1.2.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,581 - mmcv - INFO -
# backbone.layer1.2.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,581 - mmcv - INFO -
# backbone.layer1.2.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,581 - mmcv - INFO -
# backbone.layer1.2.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,581 - mmcv - INFO -
# backbone.layer2.0.conv1.weight - torch.Size([128, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,582 - mmcv - INFO -
# backbone.layer2.0.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,582 - mmcv - INFO -
# backbone.layer2.0.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,582 - mmcv - INFO -
# backbone.layer2.0.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,582 - mmcv - INFO -
# backbone.layer2.0.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,583 - mmcv - INFO -
# backbone.layer2.0.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,583 - mmcv - INFO -
# backbone.layer2.0.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,583 - mmcv - INFO -
# backbone.layer2.0.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,583 - mmcv - INFO -
# backbone.layer2.0.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,583 - mmcv - INFO -
# backbone.layer2.0.downsample.0.weight - torch.Size([512, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,584 - mmcv - INFO -
# backbone.layer2.0.downsample.1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,584 - mmcv - INFO -
# backbone.layer2.0.downsample.1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,584 - mmcv - INFO -
# backbone.layer2.1.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,584 - mmcv - INFO -
# backbone.layer2.1.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,585 - mmcv - INFO -
# backbone.layer2.1.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,585 - mmcv - INFO -
# backbone.layer2.1.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,585 - mmcv - INFO -
# backbone.layer2.1.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,586 - mmcv - INFO -
# backbone.layer2.1.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,586 - mmcv - INFO -
# backbone.layer2.1.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,586 - mmcv - INFO -
# backbone.layer2.1.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,587 - mmcv - INFO -
# backbone.layer2.1.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,587 - mmcv - INFO -
# backbone.layer2.2.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,587 - mmcv - INFO -
# backbone.layer2.2.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,587 - mmcv - INFO -
# backbone.layer2.2.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,588 - mmcv - INFO -
# backbone.layer2.2.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,588 - mmcv - INFO -
# backbone.layer2.2.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,588 - mmcv - INFO -
# backbone.layer2.2.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,588 - mmcv - INFO -
# backbone.layer2.2.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,589 - mmcv - INFO -
# backbone.layer2.2.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,589 - mmcv - INFO -
# backbone.layer2.2.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,589 - mmcv - INFO -
# backbone.layer2.3.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,589 - mmcv - INFO -
# backbone.layer2.3.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,590 - mmcv - INFO -
# backbone.layer2.3.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,590 - mmcv - INFO -
# backbone.layer2.3.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,590 - mmcv - INFO -
# backbone.layer2.3.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,590 - mmcv - INFO -
# backbone.layer2.3.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,591 - mmcv - INFO -
# backbone.layer2.3.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,591 - mmcv - INFO -
# backbone.layer2.3.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,591 - mmcv - INFO -
# backbone.layer2.3.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,591 - mmcv - INFO -
# backbone.layer3.0.conv1.weight - torch.Size([256, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,592 - mmcv - INFO -
# backbone.layer3.0.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,592 - mmcv - INFO -
# backbone.layer3.0.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,592 - mmcv - INFO -
# backbone.layer3.0.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,592 - mmcv - INFO -
# backbone.layer3.0.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,593 - mmcv - INFO -
# backbone.layer3.0.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,593 - mmcv - INFO -
# backbone.layer3.0.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,593 - mmcv - INFO -
# backbone.layer3.0.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,593 - mmcv - INFO -
# backbone.layer3.0.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,594 - mmcv - INFO -
# backbone.layer3.0.downsample.0.weight - torch.Size([1024, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,594 - mmcv - INFO -
# backbone.layer3.0.downsample.1.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,594 - mmcv - INFO -
# backbone.layer3.0.downsample.1.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,594 - mmcv - INFO -
# backbone.layer3.1.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,595 - mmcv - INFO -
# backbone.layer3.1.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,595 - mmcv - INFO -
# backbone.layer3.1.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,595 - mmcv - INFO -
# backbone.layer3.1.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,595 - mmcv - INFO -
# backbone.layer3.1.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,596 - mmcv - INFO -
# backbone.layer3.1.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,596 - mmcv - INFO -
# backbone.layer3.1.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,596 - mmcv - INFO -
# backbone.layer3.1.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,596 - mmcv - INFO -
# backbone.layer3.1.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,597 - mmcv - INFO -
# backbone.layer3.2.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,597 - mmcv - INFO -
# backbone.layer3.2.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,597 - mmcv - INFO -
# backbone.layer3.2.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,597 - mmcv - INFO -
# backbone.layer3.2.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,598 - mmcv - INFO -
# backbone.layer3.2.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,598 - mmcv - INFO -
# backbone.layer3.2.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,598 - mmcv - INFO -
# backbone.layer3.2.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,599 - mmcv - INFO -
# backbone.layer3.2.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,599 - mmcv - INFO -
# backbone.layer3.2.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,599 - mmcv - INFO -
# backbone.layer3.3.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,599 - mmcv - INFO -
# backbone.layer3.3.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,600 - mmcv - INFO -
# backbone.layer3.3.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,600 - mmcv - INFO -
# backbone.layer3.3.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,600 - mmcv - INFO -
# backbone.layer3.3.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,600 - mmcv - INFO -
# backbone.layer3.3.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,601 - mmcv - INFO -
# backbone.layer3.3.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,601 - mmcv - INFO -
# backbone.layer3.3.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,601 - mmcv - INFO -
# backbone.layer3.3.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,601 - mmcv - INFO -
# backbone.layer3.4.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,602 - mmcv - INFO -
# backbone.layer3.4.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,602 - mmcv - INFO -
# backbone.layer3.4.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,602 - mmcv - INFO -
# backbone.layer3.4.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,602 - mmcv - INFO -
# backbone.layer3.4.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,603 - mmcv - INFO -
# backbone.layer3.4.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,603 - mmcv - INFO -
# backbone.layer3.4.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,603 - mmcv - INFO -
# backbone.layer3.4.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,603 - mmcv - INFO -
# backbone.layer3.4.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,604 - mmcv - INFO -
# backbone.layer3.5.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,604 - mmcv - INFO -
# backbone.layer3.5.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,604 - mmcv - INFO -
# backbone.layer3.5.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,604 - mmcv - INFO -
# backbone.layer3.5.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,605 - mmcv - INFO -
# backbone.layer3.5.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,605 - mmcv - INFO -
# backbone.layer3.5.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,605 - mmcv - INFO -
# backbone.layer3.5.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,605 - mmcv - INFO -
# backbone.layer3.5.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,606 - mmcv - INFO -
# backbone.layer3.5.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,606 - mmcv - INFO -
# backbone.layer4.0.conv1.weight - torch.Size([512, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,606 - mmcv - INFO -
# backbone.layer4.0.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,606 - mmcv - INFO -
# backbone.layer4.0.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,607 - mmcv - INFO -
# backbone.layer4.0.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,607 - mmcv - INFO -
# backbone.layer4.0.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,607 - mmcv - INFO -
# backbone.layer4.0.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,607 - mmcv - INFO -
# backbone.layer4.0.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,608 - mmcv - INFO -
# backbone.layer4.0.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,608 - mmcv - INFO -
# backbone.layer4.0.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,608 - mmcv - INFO -
# backbone.layer4.0.downsample.0.weight - torch.Size([2048, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,609 - mmcv - INFO -
# backbone.layer4.0.downsample.1.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,609 - mmcv - INFO -
# backbone.layer4.0.downsample.1.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,609 - mmcv - INFO -
# backbone.layer4.1.conv1.weight - torch.Size([512, 2048, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,609 - mmcv - INFO -
# backbone.layer4.1.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,610 - mmcv - INFO -
# backbone.layer4.1.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,610 - mmcv - INFO -
# backbone.layer4.1.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,610 - mmcv - INFO -
# backbone.layer4.1.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,610 - mmcv - INFO -
# backbone.layer4.1.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,611 - mmcv - INFO -
# backbone.layer4.1.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,611 - mmcv - INFO -
# backbone.layer4.1.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,611 - mmcv - INFO -
# backbone.layer4.1.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,611 - mmcv - INFO -
# backbone.layer4.2.conv1.weight - torch.Size([512, 2048, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,612 - mmcv - INFO -
# backbone.layer4.2.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,612 - mmcv - INFO -
# backbone.layer4.2.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,612 - mmcv - INFO -
# backbone.layer4.2.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,612 - mmcv - INFO -
# backbone.layer4.2.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,613 - mmcv - INFO -
# backbone.layer4.2.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,613 - mmcv - INFO -
# backbone.layer4.2.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,613 - mmcv - INFO -
# backbone.layer4.2.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,613 - mmcv - INFO -
# backbone.layer4.2.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:39:14,614 - mmcv - INFO -
# neck.lateral_convs.0.conv.weight - torch.Size([256, 512, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-04-30 11:39:14,614 - mmcv - INFO -
# neck.lateral_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:39:14,614 - mmcv - INFO -
# neck.lateral_convs.1.conv.weight - torch.Size([256, 1024, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-04-30 11:39:14,614 - mmcv - INFO -
# neck.lateral_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:39:14,615 - mmcv - INFO -
# neck.lateral_convs.2.conv.weight - torch.Size([256, 2048, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-04-30 11:39:14,615 - mmcv - INFO -
# neck.lateral_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:39:14,615 - mmcv - INFO -
# neck.fpn_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-04-30 11:39:14,615 - mmcv - INFO -
# neck.fpn_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:39:14,616 - mmcv - INFO -
# neck.fpn_convs.1.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-04-30 11:39:14,616 - mmcv - INFO -
# neck.fpn_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:39:14,616 - mmcv - INFO -
# neck.fpn_convs.2.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-04-30 11:39:14,616 - mmcv - INFO -
# neck.fpn_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:39:14,617 - mmcv - INFO -
# neck.fpn_convs.3.conv.weight - torch.Size([256, 2048, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-04-30 11:39:14,617 - mmcv - INFO -
# neck.fpn_convs.3.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:39:14,617 - mmcv - INFO -
# neck.fpn_convs.4.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-04-30 11:39:14,618 - mmcv - INFO -
# neck.fpn_convs.4.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:39:14,618 - mmcv - INFO -
# bbox_head.cls_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-04-30 11:39:14,618 - mmcv - INFO -
# bbox_head.cls_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:39:14,618 - mmcv - INFO -
# bbox_head.cls_convs.1.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-04-30 11:39:14,619 - mmcv - INFO -
# bbox_head.cls_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:39:14,619 - mmcv - INFO -
# bbox_head.cls_convs.2.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-04-30 11:39:14,619 - mmcv - INFO -
# bbox_head.cls_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:39:14,619 - mmcv - INFO -
# bbox_head.cls_convs.3.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-04-30 11:39:14,620 - mmcv - INFO -
# bbox_head.cls_convs.3.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:39:14,620 - mmcv - INFO -
# bbox_head.reg_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-04-30 11:39:14,620 - mmcv - INFO -
# bbox_head.reg_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:39:14,620 - mmcv - INFO -
# bbox_head.reg_convs.1.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-04-30 11:39:14,621 - mmcv - INFO -
# bbox_head.reg_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:39:14,621 - mmcv - INFO -
# bbox_head.reg_convs.2.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-04-30 11:39:14,621 - mmcv - INFO -
# bbox_head.reg_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:39:14,621 - mmcv - INFO -
# bbox_head.reg_convs.3.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-04-30 11:39:14,622 - mmcv - INFO -
# bbox_head.reg_convs.3.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:39:14,622 - mmcv - INFO -
# bbox_head.retina_cls.weight - torch.Size([27, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=-4.59511985013459
#
# 2022-04-30 11:39:14,622 - mmcv - INFO -
# bbox_head.retina_cls.bias - torch.Size([27]):
# NormalInit: mean=0, std=0.01, bias=-4.59511985013459
#
# 2022-04-30 11:39:14,622 - mmcv - INFO -
# bbox_head.retina_reg.weight - torch.Size([36, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-04-30 11:39:14,623 - mmcv - INFO -
# bbox_head.retina_reg.bias - torch.Size([36]):
# NormalInit: mean=0, std=0.01, bias=0
# load checkpoint from local path: checkpoints/retinanet/retinanet_r50_fpn_1x_coco_20200130-c2398f9e.pth
# The model and loaded state dict do not match exactly
#
# size mismatch for bbox_head.retina_cls.weight: copying a param with shape torch.Size([720, 256, 3, 3]) from checkpoint, the shape in current model is torch.Size([27, 256, 3, 3]).
# size mismatch for bbox_head.retina_cls.bias: copying a param with shape torch.Size([720]) from checkpoint, the shape in current model is torch.Size([27]).

# %%
metrics = [COCOMetric(metric_type=COCOMetricType.bbox)]
learner = model_type.fastai.learner(dls=[train_dl, valid_dl], model=model, metrics=metrics)

# %%
learner.lr_find()
# Out:
# /home/tupleteam/.local/lib/python3.8/site-packages/mmdet/core/anchor/anchor_generator.py:324: UserWarning: ``grid_anchors`` would be deprecated soon. Please use ``grid_priors``
#   warnings.warn('``grid_anchors`` would be deprecated soon. '
# /home/tupleteam/.local/lib/python3.8/site-packages/mmdet/core/anchor/anchor_generator.py:360: UserWarning: ``single_level_grid_anchors`` would be deprecated soon. Please use ``single_level_grid_priors``
#   warnings.warn(
# SuggestedLRs(valley=0.00013182566908653826)

# %%
learner.fine_tune(20, 1e-4, freeze_epochs=1)

# %%
from icevision.models import *

# %%
m = ClassMap(list(df['label'].unique()))
m.get_classes()
# Out:
# ['background', 'cat', 'monkey', 'dog']

# %%
# เซฟโมเดลด้วยคำสั่ง `save_icevision_checkpoint`
checkpoint_path = "monkeycatdog_det.pth"
save_icevision_checkpoint(
    model, 
    model_name='mmdet.retinanet', 
    backbone_name='resnet50_fpn_1x',
    classes=m.get_classes(),
    img_size=224,
    filename=checkpoint_path,
    meta={"icevision_version": "0.12.0"}
)

# %% [markdown]
# ## **Example prediction**
#
# ลองใช้โมเดลทำนายผลใน validation dataset `valid_ds`

# %%
# โหลดโมเดลที่เซฟมาเพื่อทำนายผลใน validation set
model_loaded = model_from_checkpoint("monkeycatdog_det.pth")
# Out:
# load checkpoint from local path: monkeycatdog_det.pth
# 2022-04-30 11:44:42,026 - mmcv - INFO - initialize ResNet with init_cfg {'type': 'Pretrained', 'checkpoint': 'torchvision://resnet50'}
# 2022-04-30 11:44:42,027 - mmcv - INFO - load model from: torchvision://resnet50
# 2022-04-30 11:44:42,027 - mmcv - INFO - load checkpoint from torchvision path: torchvision://resnet50
# 2022-04-30 11:44:42,070 - mmcv - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 2022-04-30 11:44:42,079 - mmcv - INFO - initialize FPN with init_cfg {'type': 'Xavier', 'layer': 'Conv2d', 'distribution': 'uniform'}
# 2022-04-30 11:44:42,116 - mmcv - INFO - initialize RetinaHead with init_cfg {'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01, 'override': {'type': 'Normal', 'name': 'retina_cls', 'std': 0.01, 'bias_prob': 0.01}}
# 2022-04-30 11:44:42,143 - mmcv - INFO -
# backbone.conv1.weight - torch.Size([64, 3, 7, 7]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,143 - mmcv - INFO -
# backbone.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,144 - mmcv - INFO -
# backbone.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,144 - mmcv - INFO -
# backbone.layer1.0.conv1.weight - torch.Size([64, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,145 - mmcv - INFO -
# backbone.layer1.0.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,145 - mmcv - INFO -
# backbone.layer1.0.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,145 - mmcv - INFO -
# backbone.layer1.0.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,146 - mmcv - INFO -
# backbone.layer1.0.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,146 - mmcv - INFO -
# backbone.layer1.0.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,147 - mmcv - INFO -
# backbone.layer1.0.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,147 - mmcv - INFO -
# backbone.layer1.0.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,147 - mmcv - INFO -
# backbone.layer1.0.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,148 - mmcv - INFO -
# backbone.layer1.0.downsample.0.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,148 - mmcv - INFO -
# backbone.layer1.0.downsample.1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,148 - mmcv - INFO -
# backbone.layer1.0.downsample.1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,149 - mmcv - INFO -
# backbone.layer1.1.conv1.weight - torch.Size([64, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,149 - mmcv - INFO -
# backbone.layer1.1.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,149 - mmcv - INFO -
# backbone.layer1.1.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,150 - mmcv - INFO -
# backbone.layer1.1.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,150 - mmcv - INFO -
# backbone.layer1.1.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,150 - mmcv - INFO -
# backbone.layer1.1.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,151 - mmcv - INFO -
# backbone.layer1.1.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,151 - mmcv - INFO -
# backbone.layer1.1.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,151 - mmcv - INFO -
# backbone.layer1.1.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,152 - mmcv - INFO -
# backbone.layer1.2.conv1.weight - torch.Size([64, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,152 - mmcv - INFO -
# backbone.layer1.2.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,152 - mmcv - INFO -
# backbone.layer1.2.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,153 - mmcv - INFO -
# backbone.layer1.2.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,153 - mmcv - INFO -
# backbone.layer1.2.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,153 - mmcv - INFO -
# backbone.layer1.2.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,153 - mmcv - INFO -
# backbone.layer1.2.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,154 - mmcv - INFO -
# backbone.layer1.2.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,154 - mmcv - INFO -
# backbone.layer1.2.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,154 - mmcv - INFO -
# backbone.layer2.0.conv1.weight - torch.Size([128, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,154 - mmcv - INFO -
# backbone.layer2.0.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,155 - mmcv - INFO -
# backbone.layer2.0.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,155 - mmcv - INFO -
# backbone.layer2.0.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,155 - mmcv - INFO -
# backbone.layer2.0.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,155 - mmcv - INFO -
# backbone.layer2.0.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,156 - mmcv - INFO -
# backbone.layer2.0.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,156 - mmcv - INFO -
# backbone.layer2.0.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,156 - mmcv - INFO -
# backbone.layer2.0.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,156 - mmcv - INFO -
# backbone.layer2.0.downsample.0.weight - torch.Size([512, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,157 - mmcv - INFO -
# backbone.layer2.0.downsample.1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,157 - mmcv - INFO -
# backbone.layer2.0.downsample.1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,157 - mmcv - INFO -
# backbone.layer2.1.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,157 - mmcv - INFO -
# backbone.layer2.1.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,158 - mmcv - INFO -
# backbone.layer2.1.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,158 - mmcv - INFO -
# backbone.layer2.1.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,158 - mmcv - INFO -
# backbone.layer2.1.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,158 - mmcv - INFO -
# backbone.layer2.1.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,159 - mmcv - INFO -
# backbone.layer2.1.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,159 - mmcv - INFO -
# backbone.layer2.1.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,159 - mmcv - INFO -
# backbone.layer2.1.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,159 - mmcv - INFO -
# backbone.layer2.2.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,160 - mmcv - INFO -
# backbone.layer2.2.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,160 - mmcv - INFO -
# backbone.layer2.2.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,160 - mmcv - INFO -
# backbone.layer2.2.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,160 - mmcv - INFO -
# backbone.layer2.2.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,161 - mmcv - INFO -
# backbone.layer2.2.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,161 - mmcv - INFO -
# backbone.layer2.2.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,161 - mmcv - INFO -
# backbone.layer2.2.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,161 - mmcv - INFO -
# backbone.layer2.2.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,162 - mmcv - INFO -
# backbone.layer2.3.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,162 - mmcv - INFO -
# backbone.layer2.3.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,162 - mmcv - INFO -
# backbone.layer2.3.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,162 - mmcv - INFO -
# backbone.layer2.3.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,163 - mmcv - INFO -
# backbone.layer2.3.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,163 - mmcv - INFO -
# backbone.layer2.3.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,163 - mmcv - INFO -
# backbone.layer2.3.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,163 - mmcv - INFO -
# backbone.layer2.3.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,164 - mmcv - INFO -
# backbone.layer2.3.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,164 - mmcv - INFO -
# backbone.layer3.0.conv1.weight - torch.Size([256, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,164 - mmcv - INFO -
# backbone.layer3.0.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,164 - mmcv - INFO -
# backbone.layer3.0.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,165 - mmcv - INFO -
# backbone.layer3.0.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,165 - mmcv - INFO -
# backbone.layer3.0.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,166 - mmcv - INFO -
# backbone.layer3.0.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,166 - mmcv - INFO -
# backbone.layer3.0.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,166 - mmcv - INFO -
# backbone.layer3.0.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,167 - mmcv - INFO -
# backbone.layer3.0.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,167 - mmcv - INFO -
# backbone.layer3.0.downsample.0.weight - torch.Size([1024, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,167 - mmcv - INFO -
# backbone.layer3.0.downsample.1.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,168 - mmcv - INFO -
# backbone.layer3.0.downsample.1.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,168 - mmcv - INFO -
# backbone.layer3.1.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,168 - mmcv - INFO -
# backbone.layer3.1.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,169 - mmcv - INFO -
# backbone.layer3.1.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,169 - mmcv - INFO -
# backbone.layer3.1.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,169 - mmcv - INFO -
# backbone.layer3.1.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,170 - mmcv - INFO -
# backbone.layer3.1.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,170 - mmcv - INFO -
# backbone.layer3.1.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,171 - mmcv - INFO -
# backbone.layer3.1.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,171 - mmcv - INFO -
# backbone.layer3.1.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,171 - mmcv - INFO -
# backbone.layer3.2.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,172 - mmcv - INFO -
# backbone.layer3.2.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,172 - mmcv - INFO -
# backbone.layer3.2.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,172 - mmcv - INFO -
# backbone.layer3.2.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,173 - mmcv - INFO -
# backbone.layer3.2.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,173 - mmcv - INFO -
# backbone.layer3.2.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,173 - mmcv - INFO -
# backbone.layer3.2.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,173 - mmcv - INFO -
# backbone.layer3.2.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,174 - mmcv - INFO -
# backbone.layer3.2.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,174 - mmcv - INFO -
# backbone.layer3.3.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,175 - mmcv - INFO -
# backbone.layer3.3.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,175 - mmcv - INFO -
# backbone.layer3.3.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,175 - mmcv - INFO -
# backbone.layer3.3.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,175 - mmcv - INFO -
# backbone.layer3.3.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,176 - mmcv - INFO -
# backbone.layer3.3.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,176 - mmcv - INFO -
# backbone.layer3.3.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,176 - mmcv - INFO -
# backbone.layer3.3.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,176 - mmcv - INFO -
# backbone.layer3.3.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,177 - mmcv - INFO -
# backbone.layer3.4.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,177 - mmcv - INFO -
# backbone.layer3.4.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,177 - mmcv - INFO -
# backbone.layer3.4.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,177 - mmcv - INFO -
# backbone.layer3.4.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,178 - mmcv - INFO -
# backbone.layer3.4.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,178 - mmcv - INFO -
# backbone.layer3.4.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,178 - mmcv - INFO -
# backbone.layer3.4.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,178 - mmcv - INFO -
# backbone.layer3.4.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,179 - mmcv - INFO -
# backbone.layer3.4.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,179 - mmcv - INFO -
# backbone.layer3.5.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,179 - mmcv - INFO -
# backbone.layer3.5.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,179 - mmcv - INFO -
# backbone.layer3.5.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,180 - mmcv - INFO -
# backbone.layer3.5.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,180 - mmcv - INFO -
# backbone.layer3.5.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,180 - mmcv - INFO -
# backbone.layer3.5.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,180 - mmcv - INFO -
# backbone.layer3.5.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,181 - mmcv - INFO -
# backbone.layer3.5.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,181 - mmcv - INFO -
# backbone.layer3.5.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,181 - mmcv - INFO -
# backbone.layer4.0.conv1.weight - torch.Size([512, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,182 - mmcv - INFO -
# backbone.layer4.0.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,182 - mmcv - INFO -
# backbone.layer4.0.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,182 - mmcv - INFO -
# backbone.layer4.0.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,182 - mmcv - INFO -
# backbone.layer4.0.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,183 - mmcv - INFO -
# backbone.layer4.0.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,183 - mmcv - INFO -
# backbone.layer4.0.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,183 - mmcv - INFO -
# backbone.layer4.0.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,183 - mmcv - INFO -
# backbone.layer4.0.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,184 - mmcv - INFO -
# backbone.layer4.0.downsample.0.weight - torch.Size([2048, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,184 - mmcv - INFO -
# backbone.layer4.0.downsample.1.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,184 - mmcv - INFO -
# backbone.layer4.0.downsample.1.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,184 - mmcv - INFO -
# backbone.layer4.1.conv1.weight - torch.Size([512, 2048, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,185 - mmcv - INFO -
# backbone.layer4.1.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,185 - mmcv - INFO -
# backbone.layer4.1.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,185 - mmcv - INFO -
# backbone.layer4.1.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,185 - mmcv - INFO -
# backbone.layer4.1.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,186 - mmcv - INFO -
# backbone.layer4.1.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,186 - mmcv - INFO -
# backbone.layer4.1.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,186 - mmcv - INFO -
# backbone.layer4.1.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,186 - mmcv - INFO -
# backbone.layer4.1.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,187 - mmcv - INFO -
# backbone.layer4.2.conv1.weight - torch.Size([512, 2048, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,187 - mmcv - INFO -
# backbone.layer4.2.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,187 - mmcv - INFO -
# backbone.layer4.2.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,187 - mmcv - INFO -
# backbone.layer4.2.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,188 - mmcv - INFO -
# backbone.layer4.2.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,188 - mmcv - INFO -
# backbone.layer4.2.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,188 - mmcv - INFO -
# backbone.layer4.2.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,188 - mmcv - INFO -
# backbone.layer4.2.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,189 - mmcv - INFO -
# backbone.layer4.2.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-04-30 11:44:42,189 - mmcv - INFO -
# neck.lateral_convs.0.conv.weight - torch.Size([256, 512, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-04-30 11:44:42,189 - mmcv - INFO -
# neck.lateral_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:44:42,189 - mmcv - INFO -
# neck.lateral_convs.1.conv.weight - torch.Size([256, 1024, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-04-30 11:44:42,190 - mmcv - INFO -
# neck.lateral_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:44:42,190 - mmcv - INFO -
# neck.lateral_convs.2.conv.weight - torch.Size([256, 2048, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-04-30 11:44:42,190 - mmcv - INFO -
# neck.lateral_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:44:42,190 - mmcv - INFO -
# neck.fpn_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-04-30 11:44:42,191 - mmcv - INFO -
# neck.fpn_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:44:42,191 - mmcv - INFO -
# neck.fpn_convs.1.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-04-30 11:44:42,191 - mmcv - INFO -
# neck.fpn_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:44:42,191 - mmcv - INFO -
# neck.fpn_convs.2.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-04-30 11:44:42,192 - mmcv - INFO -
# neck.fpn_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:44:42,192 - mmcv - INFO -
# neck.fpn_convs.3.conv.weight - torch.Size([256, 2048, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-04-30 11:44:42,192 - mmcv - INFO -
# neck.fpn_convs.3.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:44:42,192 - mmcv - INFO -
# neck.fpn_convs.4.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-04-30 11:44:42,193 - mmcv - INFO -
# neck.fpn_convs.4.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:44:42,193 - mmcv - INFO -
# bbox_head.cls_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-04-30 11:44:42,193 - mmcv - INFO -
# bbox_head.cls_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:44:42,193 - mmcv - INFO -
# bbox_head.cls_convs.1.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-04-30 11:44:42,194 - mmcv - INFO -
# bbox_head.cls_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:44:42,194 - mmcv - INFO -
# bbox_head.cls_convs.2.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-04-30 11:44:42,194 - mmcv - INFO -
# bbox_head.cls_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:44:42,194 - mmcv - INFO -
# bbox_head.cls_convs.3.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-04-30 11:44:42,195 - mmcv - INFO -
# bbox_head.cls_convs.3.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:44:42,195 - mmcv - INFO -
# bbox_head.reg_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-04-30 11:44:42,195 - mmcv - INFO -
# bbox_head.reg_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:44:42,196 - mmcv - INFO -
# bbox_head.reg_convs.1.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-04-30 11:44:42,196 - mmcv - INFO -
# bbox_head.reg_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:44:42,196 - mmcv - INFO -
# bbox_head.reg_convs.2.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-04-30 11:44:42,196 - mmcv - INFO -
# bbox_head.reg_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:44:42,197 - mmcv - INFO -
# bbox_head.reg_convs.3.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-04-30 11:44:42,197 - mmcv - INFO -
# bbox_head.reg_convs.3.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2022-04-30 11:44:42,197 - mmcv - INFO -
# bbox_head.retina_cls.weight - torch.Size([27, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=-4.59511985013459
#
# 2022-04-30 11:44:42,197 - mmcv - INFO -
# bbox_head.retina_cls.bias - torch.Size([27]):
# NormalInit: mean=0, std=0.01, bias=-4.59511985013459
#
# 2022-04-30 11:44:42,198 - mmcv - INFO -
# bbox_head.retina_reg.weight - torch.Size([36, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-04-30 11:44:42,198 - mmcv - INFO -
# bbox_head.retina_reg.bias - torch.Size([36]):
# NormalInit: mean=0, std=0.01, bias=0

# %%
model_type = model_loaded["model_type"]
backbone = model_loaded["backbone"]
class_map = model_loaded["class_map"]
img_size = model_loaded["img_size"]
model_type, backbone, class_map, img_size
# Out:
# (<module 'icevision.models.mmdet.models.retinanet' from '/home/tupleteam/git/icevision/icevision/models/mmdet/models/retinanet/__init__.py'>,
#  <icevision.models.mmdet.models.retinanet.backbones.backbone_config.MMDetRetinanetBackboneConfig at 0x7fc6dba93ee0>,
#  <ClassMap: {'background': 0, 'cat': 1, 'monkey': 2, 'dog': 3}>,
#  224)

# %%
model_type.show_results(model_loaded["model"], valid_ds, detection_threshold=0.4)
